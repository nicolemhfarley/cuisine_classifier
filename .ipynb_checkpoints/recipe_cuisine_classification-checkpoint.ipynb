# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import json
import re
import operator

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ### Kaggle recipe ingredients training dataset

# %%
with open('ingredient_train.json', 'r') as json_f:
    json_train_data = json.load(json_f)

# %%
with open('ingredient_test.json', 'r') as json_f:
    json_test_data = json.load(json_f)

# %%
type(json_train_data)
# Out:
# list

# %%
len(json_train_data), len(json_test_data)
# Out:
# (39774, 9944)

# %%
json_train_data[0]
# Out:
# {'id': 10259,
#  'cuisine': 'greek',
#  'ingredients': ['romaine lettuce',
#   'black olives',
#   'grape tomatoes',
#   'garlic',
#   'pepper',
#   'purple onion',
#   'seasoning',
#   'garbanzo beans',
#   'feta cheese crumbles']}

# %%
type(json_train_data[0])
# Out:
# dict

# %% [markdown]
# #### get training and test data into separate pandas df

# %%
cuisine_data = pd.DataFrame(json_train_data)

# %%
cuisine_data.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
cuisine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39774 entries, 0 to 39773
# Data columns (total 3 columns):
# cuisine        39774 non-null object
# id             39774 non-null int64
# ingredients    39774 non-null object
# dtypes: int64(1), object(2)
# memory usage: 932.3+ KB

# %%
# cuisine_data.drop('id', axis=1, inplace=True)

# %%
cuisine_data.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
cuisine_data['cuisine'].value_counts()
# Out:
# italian         7838
# mexican         6438
# southern_us     4320
# indian          3003
# chinese         2673
# french          2646
# cajun_creole    1546
# thai            1539
# japanese        1423
# greek           1175
# spanish          989
# korean           830
# vietnamese       825
# moroccan         821
# british          804
# filipino         755
# irish            667
# jamaican         526
# russian          489
# brazilian        467
# Name: cuisine, dtype: int64

# %%
# split into X and y
X = cuisine_data['ingredients']
y = cuisine_data['cuisine']

# %%
# split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.shape, type(X_train)
# Out:
# ((29830,), pandas.core.series.Series)

# %%
labels = y_train.unique()

# %%
labels
# Out:
# array(['mexican', 'japanese', 'southern_us', 'italian', 'indian',
#        'chinese', 'filipino', 'spanish', 'vietnamese', 'french',
#        'moroccan', 'greek', 'russian', 'jamaican', 'cajun_creole',
#        'korean', 'irish', 'thai', 'british', 'brazilian'], dtype=object)

# %%
ids = cuisine_data['id'].unique()
len(ids)
# Out:
# 39774

# %%
# to get on list containing all words in all lists in X
corpus = [i for sublist in X for i in sublist]

# %%
# tfidf = TfidfVectorizer(tokenizer=lambda i:i.split(","))

# %%
# converted_train = map(lambda i:",".join(i), X_train)

# %% [markdown]
# #### using Tfidf vectorizer

# %%
vec = TfidfVectorizer(stop_words='english', tokenizer=lambda x:x, lowercase=False,\
                      token_pattern='\w+', ngram_range=(1,1))

# %%
train_data = vec.fit_transform(X_train.values)

# %%
test_data = vec.transform(X_test.values)

# %%
# get top 10 features of vec
vec.get_feature_names()[:10]
# Out:
# ['(    oz.) tomato sauce',
#  '(   oz.) tomato paste',
#  '(10 oz.) frozen chopped spinach',
#  '(10 oz.) frozen chopped spinach, thawed and squeezed dry',
#  '(14 oz.) sweetened condensed milk',
#  '(14.5 oz.) diced tomatoes',
#  '(15 oz.) refried beans',
#  '1% low-fat buttermilk',
#  '1% low-fat chocolate milk',
#  '1% low-fat cottage cheese']

# %%
vec.vocabulary_
# Out:
# {'quinoa': 4542,
#  'purple onion': 4516,
#  'pepper': 4199,
#  'jalapeno chilies': 3165,
#  'chicken broth': 1369,
#  'roma tomatoes': 4805,
#  'salt': 4890,
#  'lime': 3450,
#  'cilantro': 1605,
#  'minced garlic': 3784,
#  'ginger': 2681,
#  'canola oil': 1218,
#  'sugar': 5422,
#  'napa cabbage': 3896,
#  'scallions': 4951,
#  'miso paste': 3813,
#  'ground pork': 2911,
#  'carrots': 1255,
#  'milk': 3773,
#  'bacon': 651,
#  'whole wheat breadcrumbs': 6055,
#  'eggs': 2229,
#  'baking potatoes': 673,
#  'all-purpose flour': 481,
#  'half & half': 2959,
#  'shredded sharp cheddar cheese': 5095,
#  'italian seasoning': 3151,
#  'butter': 1105,
#  'fresh herbs': 2485,
#  'white onion': 5993,
#  'button mushrooms': 1129,
#  'boneless skinless chicken breast halves': 959,
#  'grated parmesan cheese': 2802,
#  'rotini': 4829,
#  'crushed tomatoes': 1926,
#  'garlic': 2647,
#  'vegetable oil': 5871,
#  'white sugar': 6005,
#  'water': 5924,
#  'tamarind concentrate': 5541,
#  'cayenne pepper': 1282,
#  'dates': 2012,
#  'sesame seeds': 5015,
#  'oil': 3979,
#  'white pepper': 5995,
#  'sesame oil': 5012,
#  'soy sauce': 5286,
#  'garlic powder': 2664,
#  'cumin': 1951,
#  'green cabbage': 2829,
#  'chinese five-spice powder': 1468,
#  'olive oil': 3995,
#  'flour': 2414,
#  'whole peeled tomatoes': 6043,
#  'eggplant': 2227,
#  'mozzarella cheese': 3854,
#  'parmigiano reggiano cheese': 4108,
#  'fresh basil': 2457,
#  'french bread': 2444,
#  'extra-virgin olive oil': 2273,
#  'beef tenderloin steaks': 794,
#  'ground black pepper': 2879,
#  'chopped fresh thyme': 1560,
#  'cider vinegar': 1604,
#  'cooking spray': 1776,
#  'port': 4425,
#  'tomatoes': 5662,
#  'finely chopped onion': 2362,
#  'pecorino romano cheese': 4182,
#  'corn syrup': 1798,
#  'parmigiano-reggiano cheese': 4109,
#  'kosher salt': 3298,
#  'chopped walnuts': 1573,
#  'warm water': 5920,
#  'prosciutto': 4486,
#  'arugula': 584,
#  'fresh lemon juice': 2489,
#  'black pepper': 860,
#  'dry yeast': 2184,
#  'hot pepper sauce': 3082,
#  'chile pepper': 1422,
#  'vidalia onion': 5894,
#  'baked beans': 664,
#  'ground beef': 2877,
#  'brown sugar': 1075,
#  'barbecue sauce': 698,
#  'chili powder': 1443,
#  'spinach': 5322,
#  'cooking oil': 1773,
#  'bok choy': 909,
#  'fish sauce': 2381,
#  'onions': 4012,
#  'chicken legs': 1387,
#  'fresh ginger': 2481,
#  'chayotes': 1323,
#  'mahi mahi fillets': 3633,
#  'ground cumin': 2894,
#  'balsamic vinegar': 684,
#  'hothouse cucumber': 3092,
#  'green onions': 2847,
#  'serrano chile': 5005,
#  'cherries': 1341,
#  'chopped cilantro fresh': 1553,
#  'lettuce leaves': 3420,
#  'daikon': 1983,
#  'vietnamese fish sauce': 5895,
#  'chili sauce': 1444,
#  'large egg whites': 3343,
#  'shredded carrots': 5072,
#  'deveined shrimp': 2023,
#  'fresh lime juice': 2492,
#  'panko': 4090,
#  'rice vinegar': 4752,
#  'cream': 1846,
#  'diced tomatoes in juice': 2042,
#  'ground ginger': 2899,
#  'minced onion': 3788,
#  'whole milk yoghurt': 6039,
#  'large garlic cloves': 3348,
#  'masala': 3690,
#  'tomato paste': 5656,
#  'boneless skinless chicken breasts': 960,
#  'lemon juice': 3393,
#  'baguette': 662,
#  'whole milk': 6036,
#  'cod fillets': 1679,
#  'red potato': 4639,
#  'grated lemon zest': 2798,
#  'green pepper': 2850,
#  'shredded Monterey Jack cheese': 5068,
#  'chunky salsa': 1593,
#  "Campbell's Condensed Cream of Mushroom Soup": 73,
#  'fajita size flour tortillas': 2280,
#  'mini pepperoni slices': 3798,
#  'Pillsbury™ Refrigerated Crescent Dinner Rolls': 348,
#  'mild Italian sausage': 3764,
#  'shredded mozzarella cheese': 5088,
#  'pizza sauce': 4323,
#  'chopped almonds': 1548,
#  'light corn syrup': 3430,
#  'almond extract': 485,
#  'low sodium chicken stock': 3541,
#  'red wine': 4654,
#  'garlic cloves': 2653,
#  'arborio rice': 568,
#  'unsalted butter': 5774,
#  'goat cheese': 2737,
#  'sliced mushrooms': 5159,
#  'long-grain rice': 3506,
#  'zucchini': 6181,
#  'fresh parsley': 2506,
#  'penne pasta': 4193,
#  'fresh rosemary': 2516,
#  'raisins': 4560,
#  'ground coriander': 2893,
#  'cracked black pepper': 1835,
#  'ground lamb': 2900,
#  'mayonaise': 3704,
#  'ground cayenne pepper': 2884,
#  'poblano peppers': 4345,
#  'avocado': 618,
#  'cotija': 1816,
#  'spices': 5316,
#  'corn tortillas': 1800,
#  'honey': 3044,
#  'pure vanilla extract': 4514,
#  'cardamom seeds': 1243,
#  'full fat coconut milk': 2626,
#  'yellow onion': 6148,
#  'bone in skin on chicken thigh': 915,
#  'ground cinnamon': 2890,
#  'seedless red grapes': 4983,
#  'picholine olives': 4232,
#  'ground red pepper': 2913,
#  'flat leaf parsley': 2397,
#  'light brown sugar': 3427,
#  'Hidden Valley® Original Ranch® Spicy Ranch Dressing': 175,
#  'peach slices': 4156,
#  'dijon mustard': 2048,
#  'cream sweeten whip': 1868,
#  'egg yolks': 2225,
#  'lime juice': 3451,
#  'sweetened condensed milk': 5506,
#  'graham crackers': 2761,
#  'lime zest': 3457,
#  'granulated sugar': 2775,
#  'ground cashew': 2883,
#  'small red potato': 5178,
#  'curry powder': 1972,
#  'onion powder': 4005,
#  'rice': 4737,
#  'chicken thighs': 1403,
#  'tomato sauce': 5659,
#  'heavy cream': 2997,
#  'frozen peas': 2590,
#  'dried pinto beans': 2142,
#  'salt pork': 4896,
#  'red bell pepper': 4611,
#  'egg noodles': 2218,
#  'medium shrimp': 3729,
#  'slivered almonds': 5167,
#  'dry sherry': 2181,
#  'coconut': 1659,
#  'peeled fresh ginger': 4186,
#  'vegetable broth': 5864,
#  'green cardamom pods': 2831,
#  'baby spinach leaves': 643,
#  'garam masala': 2640,
#  'kaffir lime leaves': 3212,
#  'golden brown sugar': 2744,
#  'russet potatoes': 4851,
#  'sweet potatoes & yams': 5487,
#  'sunflower oil': 5446,
#  'ground cloves': 2891,
#  'tart shells': 5574,
#  'sorrel': 5260,
#  'celery ribs': 1289,
#  'fresh dill': 2479,
#  'sour cream': 5266,
#  'parsnips': 4115,
#  'hard-boiled egg': 2976,
#  'boiling potatoes': 907,
#  'chicken stock': 1398,
#  'dill': 2050,
#  'turnips': 5751,
#  'butternut squash': 1125,
#  'low sodium chicken broth': 3540,
#  'chickpeas': 1410,
#  'boneless chicken thighs': 940,
#  'vegetables': 5880,
#  'worcestershire sauce': 6123,
#  'nutmeg': 3967,
#  'minced ginger': 3785,
#  'cinnamon': 1611,
#  'white vinegar': 6011,
#  'tortillas': 5685,
#  'fresh orange juice': 2502,
#  'allspice': 482,
#  'chili flakes': 1435,
#  'tempeh': 5585,
#  'baby spinach': 642,
#  'chicken': 1358,
#  'dried oregano': 2135,
#  'romano cheese': 4809,
#  'white rice': 5999,
#  'celery': 1284,
#  'fontina cheese': 2426,
#  'sweet onion': 5477,
#  'cooked quinoa': 1758,
#  'fresh cilantro': 2471,
#  'cajun seasoning': 1147,
#  'large shrimp': 3351,
#  'lasagna noodles': 3354,
#  'taco seasoning mix': 5527,
#  'prepar salsa': 4469,
#  'Mexican cheese blend': 298,
#  'salsa': 4887,
#  'cottage cheese': 1817,
#  'solid white tuna': 5251,
#  'feta cheese crumbles': 2334,
#  'pinenuts': 4284,
#  'linguine': 3462,
#  'sun-dried tomatoes in oil': 5440,
#  'sliced black olives': 5146,
#  'buttermilk': 1119,
#  'active dry yeast': 451,
#  'baking powder': 674,
#  'semolina flour': 5003,
#  'sea salt': 4962,
#  'baking soda': 675,
#  'vegetable shortening': 5875,
#  'ramps': 4569,
#  'lettuce': 3419,
#  'herbs': 3013,
#  'peanut butter': 4161,
#  'rice paper': 4745,
#  'hoisin sauce': 3031,
#  'turkey meat': 5741,
#  'mint': 3802,
#  'cucumber': 1945,
#  'light soy sauce': 3442,
#  'beef tenderloin': 793,
#  'dark soy sauce': 2004,
#  'crushed garlic': 1914,
#  'white sesame seeds': 6004,
#  'grape tomatoes': 2780,
#  'fine sea salt': 2360,
#  'tortilla chips': 5682,
#  'dried parsley': 2137,
#  'romaine lettuce': 4806,
#  'corn': 1783,
#  'greek yogurt': 2822,
#  'cooked bacon': 1742,
#  'dill weed': 2054,
#  'chorizo': 1574,
#  'paprika': 4098,
#  'sun-dried tomatoes': 5439,
#  'manchego cheese': 3646,
#  'corn starch': 1797,
#  'large eggs': 3345,
#  'rib eye steaks': 4731,
#  'gravy': 2810,
#  'hot sauce': 3087,
#  'buckwheat flour': 1082,
#  'fingerling potatoes': 2367,
#  'spanish paprika': 5302,
#  'green beans': 2825,
#  'sherry vinegar': 5041,
#  'cauliflower florets': 1273,
#  'potatoes': 4444,
#  'green garlic': 2839,
#  'chives': 1505,
#  'dipping sauces': 2059,
#  'Italian parsley leaves': 194,
#  'red pepper flakes': 4637,
#  'squash': 5346,
#  'white wine': 6012,
#  'parmesan cheese': 4105,
#  'ricotta cheese': 4757,
#  'white mushrooms': 5992,
#  'chicken bouillon': 1361,
#  'cooked ham': 1752,
#  'black-eyed peas': 876,
#  'grated orange peel': 2801,
#  'medium shrimp uncook': 3730,
#  'gemelli': 2672,
#  "I Can't Believe It's Not Butter!® Spread": 183,
#  'brandy': 1000,
#  'apples': 554,
#  'fresh chives': 2469,
#  'cream cheese': 1847,
#  'pickle juice': 4234,
#  'roasted red peppers': 4786,
#  'sharp cheddar cheese': 5027,
#  'salt and ground black pepper': 4891,
#  'dried sage': 2150,
#  'white cornmeal': 5979,
#  'softened butter': 5247,
#  'boiling water': 908,
#  'lemon pepper': 3396,
#  'margarine': 3669,
#  'cornmeal': 1814,
#  'catfish': 1268,
#  'fennel seeds': 2325,
#  'khoa': 3249,
#  'clarified butter': 1633,
#  'semolina': 5002,
#  'ground cardamom': 2882,
#  'rose water': 4818,
#  'saffron': 4864,
#  'steamed white rice': 5362,
#  'dark brown sugar': 1988,
#  'Sriracha': 393,
#  'short rib': 5057,
#  'mustard seeds': 3887,
#  'coriander powder': 1780,
#  'fresh curry leaves': 2477,
#  'tamarind paste': 5544,
#  'country style bread': 1824,
#  'frisee': 2543,
#  'japanese breadcrumbs': 3179,
#  'vinaigrette': 5898,
#  'banana leaves': 687,
#  'grated coconut': 2792,
#  'evaporated milk': 2257,
#  'queso fresco': 4529,
#  'sliced ham': 5154,
#  'yukon gold potatoes': 6173,
#  'chopped parsley': 1569,
#  'beef': 748,
#  'chopped garlic': 1561,
#  'asian pear': 603,
#  'asian fish sauce': 601,
#  'hot red pepper flakes': 3085,
#  'capers': 1225,
#  'cabbage': 1131,
#  'plain yogurt': 4335,
#  'dried dillweed': 2113,
#  'beer': 798,
#  'chicken breast tenders': 1367,
#  'red curry paste': 4623,
#  'light coconut milk': 3429,
#  'melted butter': 3740,
#  'sanding sugar': 4917,
#  'grated nutmeg': 2799,
#  'pie dough': 4254,
#  'vanilla extract': 5815,
#  'leeks': 3378,
#  'elbow macaroni': 2230,
#  'vegetable stock': 5878,
#  'chopped tomatoes': 1572,
#  'cannellini beans': 1211,
#  'crushed red pepper flakes': 1924,
#  'ketchup': 3241,
#  'lean ground beef': 3368,
#  'mirin': 3810,
#  'bonito': 968,
#  'chipotle chile': 1494,
#  'cilantro leaves': 1606,
#  'ancho powder': 513,
#  'black beans': 841,
#  'coarse salt': 1646,
#  'liquid': 3473,
#  'reduced sodium vegetable broth': 4700,
#  'country bread': 1819,
#  'crushed red pepper': 1923,
#  'fresh shiitake mushrooms': 2520,
#  'peanut oil': 4163,
#  'flavoring': 2405,
#  'nonstick spray': 3953,
#  'fat free milk': 2301,
#  'sweet pepper': 5480,
#  'Chinese egg noodles': 82,
#  'green olives': 2845,
#  'chicken breast halves': 1364,
#  'chopped onion': 1568,
#  'chopped celery': 1551,
#  'parsley sprigs': 4114,
#  'bay leaves': 726,
#  'chicken drumsticks': 1376,
#  'macaroni': 3625,
#  'red wine vinegar': 4656,
#  'no salt added canned tomatoes': 3916,
#  'chopped cilantro': 1552,
#  'andouille sausage': 521,
#  'cooked rice': 1759,
#  'dried thyme': 2162,
#  'beef broth': 756,
#  'filé': 2355,
#  'dried basil': 2091,
#  'dried kidney beans': 2121,
#  'won ton wrappers': 6117,
#  'shrimp': 5098,
#  'lemongrass': 3411,
#  'pork baby back ribs': 4374,
#  'unsweetened coconut milk': 5795,
#  'shallots': 5018,
#  'bananas': 692,
#  'rolled oats': 4803,
#  'greek style plain yogurt': 2820,
#  'chocolate chips': 1514,
#  'pork shoulder roast': 4412,
#  'cooked chicken': 1748,
#  'Mexican oregano': 299,
#  'chicken wings': 1406,
#  'freshly grated parmesan': 2535,
#  'kalamata': 3217,
#  'plum tomatoes': 4339,
#  'fresh parsley leaves': 2507,
#  'penne': 4192,
#  'beef rib short': 773,
#  'currant': 1965,
#  'leg of lamb': 3382,
#  'canned low sodium chicken broth': 1205,
#  'cauliflower': 1272,
#  'couscous': 1827,
#  'diced tomatoes': 2040,
#  'ground turmeric': 2926,
#  'quick-cooking tapioca': 4538,
#  'peaches': 4158,
#  'english cucumber': 2240,
#  'smoked paprika': 5198,
#  'chopped fresh mint': 1558,
#  'large egg yolks': 3344,
#  'pesto': 4223,
#  'pizza crust': 4320,
#  'peach pie filling': 4151,
#  'pie crust': 4252,
#  'muffin': 3861,
#  'powdered sugar': 4457,
#  'orange liqueur': 4024,
#  'cream cheese, soften': 1853,
#  'whipped cream': 5954,
#  'juice': 3200,
#  'chili garlic paste': 1436,
#  'tamari soy sauce': 5539,
#  'zest': 6177,
#  'bread slices': 1018,
#  'sauce': 4930,
#  'halibut fillets': 2961,
#  'small new potatoes': 5173,
#  'white wine vinegar': 6013,
#  'fresh bay leaves': 2459,
#  'lemon': 3386,
#  'granny smith apples': 2771,
#  'ice water': 3109,
#  'fresh basil leaves': 2458,
#  'peeled tomatoes': 4189,
#  'picante sauce': 4230,
#  'monterey jack': 3838,
#  'vegetarian refried beans': 5883,
#  'muenster cheese': 3859,
#  'marinara sauce': 3673,
#  'chicken pieces': 1393,
#  'chili': 1430,
#  'ground sage': 2917,
#  'ground thyme': 2922,
#  'orange juice': 4022,
#  'molasses': 3832,
#  'ground nutmeg': 2903,
#  'peppercorns': 4205,
#  'ground allspice': 2874,
#  'tofu': 5642,
#  'urad dal': 5801,
#  'poha': 4347,
#  'green chilies': 2835,
#  'neutral oil': 3909,
#  'jasmine rice': 3186,
#  'sliced carrots': 5147,
#  'beef shoulder roast': 783,
#  'riesling': 4759,
#  'pork blade steaks': 4377,
#  'thyme sprigs': 5613,
#  'clove': 1639,
#  'parsley': 4110,
#  'freeze-dried strawberries': 2441,
#  'cake': 1152,
#  'strawberries': 5397,
#  'buttercream frosting': 1116,
#  'buttermilk biscuits': 1120,
#  'turkey broth': 5734,
#  'stuffing mix': 5414,
#  'pork sausages': 4407,
#  'creole seasoning': 1883,
#  'oysters': 4063,
#  'low-fat buttermilk': 3566,
#  'dried cranberries': 2109,
#  'dried apricot': 2088,
#  'butter-margarine blend': 1115,
#  'grated orange': 2800,
#  'preserved lemon': 4478,
#  'rack of lamb': 4544,
#  'chopped pecans': 1570,
#  'apple brandy': 542,
#  'tart apples': 5570,
#  'Angostura bitters': 36,
#  'fresh mint': 2496,
#  'rum': 4843,
#  'simple syrup': 5116,
#  'champagne': 1307,
#  'marsala wine': 3681,
#  'mint sprigs': 3806,
#  'chopped fresh chives': 1556,
#  'ham': 2964,
#  'dried porcini mushrooms': 2144,
#  'green bell pepper': 2826,
#  'bay leaf': 725,
#  'brown rice': 1067,
#  'smoked ham': 5192,
#  'beef stock': 791,
#  'flour tortillas': 2416,
#  'taco seasoning': 5526,
#  'cheddar cheese': 1324,
#  'black peppercorns': 861,
#  'dried chives': 2105,
#  'pickling spices': 4250,
#  'celery seed': 1292,
#  'dark sesame oil': 2002,
#  'cremini mushrooms': 1881,
#  'white miso': 5991,
#  'low sodium soy sauce': 3551,
#  'snow peas': 5222,
#  'extra firm tofu': 2262,
#  'soba noodles': 5225,
#  'prebaked pizza crusts': 4464,
#  'broccoli florets': 1043,
#  'part-skim mozzarella cheese': 4117,
#  'portabello mushroom': 4427,
#  'olive oil flavored cooking spray': 3997,
#  'fat free less sodium chicken broth': 2299,
#  'stout': 5394,
#  'chuck steaks': 1585,
#  'prepared horseradish': 4471,
#  'mushrooms': 3879,
#  'reduced-fat sour cream': 4703,
#  'almonds': 493,
#  'anise': 529,
#  'anise extract': 530,
#  'shredded cheddar cheese': 5073,
#  'shredded lettuce': 5079,
#  'ground chuck': 2889,
#  'masa harina': 3688,
#  'garlic salt': 2666,
#  'tostada shells': 5686,
#  'seasoning salt': 4978,
#  'beef bouillon powder': 754,
#  'dried minced onion': 2128,
#  'hot water': 3091,
#  'galangal': 2638,
#  'chiles': 1429,
#  'lemon zest': 3407,
#  'mussels': 3880,
#  'thai basil': 5597,
#  'ginger root': 2689,
#  'jackfruit': 3162,
#  'shredded cabbage': 5071,
#  'baby carrots': 630,
#  'bread flour': 1014,
#  'tumeric': 5714,
#  'bone in chicken thighs': 914,
#  'lima beans': 3449,
#  'orange': 4014,
#  'olives': 4001,
#  'durum wheat flour': 2203,
#  'unflavored gelatin': 5770,
#  'navel oranges': 3906,
#  'turbinado': 5723,
#  'curds': 1956,
#  'cold milk': 1702,
#  'mandarin oranges': 3650,
#  'shortening': 5062,
#  'semi-sweet chocolate morsels': 4997,
#  'cumin seed': 1952,
#  'white hominy': 5988,
#  'greek seasoning': 2818,
#  'black olives': 858,
#  'dry white wine': 2183,
#  'korean chile paste': 3295,
#  'kimchi': 3253,
#  'soft tofu': 5242,
#  'pitted green olives': 4316,
#  'bulgur': 1091,
#  'sliced almonds': 5143,
#  'golden raisins': 2748,
#  'lemon peel': 3395,
#  'sweet paprika': 5478,
#  'cayenne': 1281,
#  'coconut cream': 1662,
#  'yellow peppers': 6150,
#  'horseradish': 3058,
#  'freshly ground pepper': 2536,
#  'ghee': 2675,
#  'moong dal': 3841,
#  'green chile': 2834,
#  'basmati rice': 719,
#  'wine vinegar': 6106,
#  'sage leaves': 4868,
#  'dried currants': 2110,
#  'chorizo sausage': 1575,
#  'corn husks': 1790,
#  'frozen corn': 2567,
#  'adobo sauce': 453,
#  'pasta sauce': 4128,
#  'fresh parmesan cheese': 2505,
#  'frozen chopped spinach': 2564,
#  'part-skim ricotta cheese': 4118,
#  'manicotti shells': 3659,
#  'sweet chili sauce': 5465,
#  'oyster sauce': 4061,
#  'fish fillets': 2378,
#  'roast beef deli meat': 4768,
#  'crumbled blue cheese': 1903,
#  'Italian bread': 190,
#  'fat-free mayonnaise': 2311,
#  'low sodium worcestershire sauce': 3563,
#  'egg whites': 2224,
#  'dark rum': 2000,
#  'yeast': 6132,
#  'candied fruit': 1179,
#  'green tomatoes': 2862,
#  'brussels sprouts': 1079,
#  'jumbo shrimp': 3207,
#  'red chili peppers': 4619,
#  'mango': 3652,
#  'vinegar': 5904,
#  'cinnamon sticks': 1616,
#  'curry leaves': 1969,
#  'genoa salami': 2673,
#  'rocket leaves': 4800,
#  'flax seed meal': 2407,
#  'cold water': 1703,
#  'stevia powder': 5371,
#  'stevia': 5369,
#  'scotch bonnet chile': 4957,
#  'coconut flour': 1665,
#  'asparagus spears': 607,
#  'swiss cheese': 5510,
#  'dry mustard': 2176,
#  'nonfat yogurt plain': 3950,
#  'pecan halves': 4178,
#  'bourbon whiskey': 991,
#  'bread crumbs': 1012,
#  'pastry': 4138,
#  'golden syrup': 2749,
#  'yellow bell pepper': 6135,
#  'steak': 5355,
#  'oregano': 4036,
#  'cherry tomatoes': 1348,
#  'sliced green onions': 5153,
#  'anchovy fillets': 516,
#  'fresh mozzarella': 2497,
#  'chickpea flour': 1409,
#  'rice flour': 4742,
#  'asafoetida': 589,
#  'dillweed': 2055,
#  'vegetable oil cooking spray': 5872,
#  'phyllo pastry': 4229,
#  'dry pasta': 2177,
#  'chopped green bell pepper': 1562,
#  'cilantro sprigs': 1609,
#  'unsweetened cocoa powder': 5794,
#  'bow-tie pasta': 992,
#  'swiss chard': 5509,
#  'white fleshed fish': 5982,
#  'fresh thyme': 2524,
#  'orange zest': 4034,
#  'coffee': 1683,
#  'chihuahua cheese': 1413,
#  'navy beans': 3907,
#  'poblano chiles': 4343,
#  'tomato purée': 5657,
#  'boneless skinless chicken tenderloins': 961,
#  'self rising flour': 4988,
#  'caster sugar': 1266,
#  'coriander seeds': 1781,
#  'red pepper': 4636,
#  'green peas': 2849,
#  'gingerroot': 2691,
#  'pecans': 4180,
#  'pasta': 4126,
#  'frozen limeade': 2576,
#  'agave nectar': 458,
#  'silver tequila': 5115,
#  'crushed ice': 1916,
#  'triple sec': 5700,
#  'frozen edamame beans': 2570,
#  'fresh oregano': 2503,
#  'pitted kalamata olives': 4317,
#  'string beans': 5405,
#  'pitas': 4311,
#  'cheese': 1329,
#  'chicken breasts': 1368,
#  'marinade': 3672,
#  'crema': 1875,
#  'sweet corn': 5468,
#  'liquid smoke': 3477,
#  'salsa verde': 4888,
#  'skinless chicken breasts': 5130,
#  'olive oil spray': 3999,
#  'reduced sodium chicken broth': 4686,
#  'whipped butter': 5953,
#  'dry bread crumbs': 2169,
#  'beaten eggs': 743,
#  'red chili powder': 4620,
#  'pearl onions': 4173,
#  'tamarind': 5540,
#  'baton': 722,
#  'fenugreek seeds': 2328,
#  'matcha green tea powder': 3698,
#  'glaze': 2701,
#  'cream of tartar': 1862,
#  'stone-ground cornmeal': 5389,
#  'blueberries': 900,
#  'ginger syrup': 2690,
#  'raspberry vinegar': 4586,
#  'crème fraîche': 1936,
#  'wild mushrooms': 6100,
#  'celery root': 1290,
#  'florets': 2411,
#  'fronds': 2547,
#  'fennel bulb': 2323,
#  'flank steak': 2392,
#  'peanuts': 4166,
#  'pork tenderloin': 4421,
#  'thai chile': 5599,
#  'beansprouts': 741,
#  'green leaf lettuce': 2842,
#  'basil leaves': 714,
#  'rice vermicelli': 4751,
#  'salted butter': 4898,
#  'crawfish': 1844,
#  'old bay seasoning': 3988,
#  'Italian seasoned breadcrumbs': 195,
#  'fresh bean': 2460,
#  'toasted sesame oil': 5632,
#  'Burgundy wine': 66,
#  'herbes de provence': 3012,
#  'cognac': 1690,
#  'littleneck clams': 3481,
#  'clam juice': 1628,
#  'garlic oil': 2660,
#  'halloumi cheese': 2963,
#  'merguez sausage': 3744,
#  'cooked white rice': 1766,
#  'fresh green peas': 2484,
#  'fresh mushrooms': 2499,
#  'mung bean sprouts': 3868,
#  'fresh blueberries': 2461,
#  'Swerve Sweetener': 400,
#  'whipping cream': 5958,
#  'vanilla': 5806,
#  'raspberry liqueur': 4582,
#  'caraway seeds': 1238,
#  'dried dill': 2112,
#  'whipped topping': 5957,
#  'sausages': 4938,
#  'syrup': 5515,
#  'blackberries': 877,
#  'cinnamon sugar': 1617,
#  'havarti cheese': 2986,
#  'vanilla bean paste': 5808,
#  'cider': 1603,
#  'diced onions': 2036,
#  'lean bacon': 3365,
#  'puffed rice': 4500,
#  'coriander': 1779,
#  'okra': 3986,
#  'garlic paste': 2661,
#  'yellow corn meal': 6139,
#  'heavy whipping cream': 2998,
#  'pickled jalapenos': 4241,
#  'diced red onions': 2039,
#  'lower sodium soy sauce': 3614,
#  'Gochujang base': 139,
#  'shiitake mushroom caps': 5046,
#  'short-grain rice': 5058,
#  'apple cider vinegar': 545,
#  'rice syrup': 4750,
#  'beef brisket': 755,
#  'rice cakes': 4740,
#  'cooked chicken breasts': 1749,
#  'low salt chicken broth': 3530,
#  'paneer': 4085,
#  'pork': 4372,
#  'chow mein noodles': 1578,
#  'jack cheese': 3160,
#  'enchilada sauce': 2237,
#  'spring onions': 5337,
#  'fontina': 2425,
#  'vanilla ice cream': 5818,
#  'figs': 2344,
#  'baked tortilla chips': 669,
#  'lime wedges': 3456,
#  'broccoli': 1042,
#  'bamboo shoots': 685,
#  'thai green curry paste': 5600,
#  'chopped ham': 1564,
#  'boneless chicken skinless thigh': 938,
#  'pineapple chunks': 4275,
#  'ras el hanout': 4577,
#  'sambal ulek': 4914,
#  'prunes': 4494,
#  'stock': 5385,
#  'spaghettini': 5298,
#  'nuts': 3970,
#  'grated carrot': 2790,
#  'whole wheat flour': 6060,
#  'chili pepper': 1441,
#  'cooking wine': 1777,
#  'long grain white rice': 3501,
#  'boneless chop pork': 941,
#  'green bell pepper, slice': 2827,
#  'stilton cheese': 5381,
#  'escarole': 2247,
#  'diced tomatoes with garlic and onion': 2043,
#  'rosemary': 4819,
#  'collard greens': 1707,
#  'shredded cheese': 5074,
#  'biscuits': 826,
#  'grits': 2872,
#  'summer squash': 5438,
#  'low-fat goat cheese': 3581,
#  'prepared pasta sauce': 4474,
#  'pitted black olives': 4313,
#  'wheat': 5939,
#  'amaretto': 498,
#  'mango chutney': 3653,
#  'walnut oil': 5916,
#  'red delicious apples': 4624,
#  'mixed greens': 3821,
#  'ponzu': 4360,
#  'ginger paste': 2686,
#  'wasabi paste': 5922,
#  'reduced sodium soy sauce': 4697,
#  'toasted sesame seeds': 5633,
#  'sweet potatoes': 5486,
#  'red miso': 4635,
#  'pea shoots': 4148,
#  'radishes': 4550,
#  'firm tofu': 2371,
#  'mung beans': 3870,
#  'yams': 6130,
#  'coconut milk': 1668,
#  'roasted salted cashews': 4788,
#  'reduced fat cheddar cheese': 4662,
#  'fresh tomatoes': 2528,
#  'lemon wedge': 3406,
#  'panko breadcrumbs': 4091,
#  'tonkatsu sauce': 5667,
#  'Mazola Corn Oil': 289,
#  'cubed beef': 1939,
#  'yoghurt': 6161,
#  'cardamom': 1241,
#  'kasuri methi': 3232,
#  'knorr chicken flavor bouillon cube': 3270,
#  'vidalia': 5893,
#  'dough': 2072,
#  'ranch dressing': 4571,
#  'dried navy beans': 2133,
#  'chees fresh mozzarella': 1327,
#  'italian vinaigrette': 3157,
#  'tomatillos': 5649,
#  'Irish whiskey': 188,
#  'irish cream liqueur': 3137,
#  'confectioners sugar': 1736,
#  'iceberg lettuce': 3111,
#  'taco sauce': 5525,
#  'chipotles in adobo': 1501,
#  'wide rice noodles': 6096,
#  'broccolini': 1048,
#  'almond butter': 484,
#  'miso': 3812,
#  'nama shoyu': 3895,
#  'papaya': 4094,
#  'hemp seeds': 3005,
#  'raspberries': 4578,
#  'chia seeds': 1357,
#  'açai': 623,
#  'granola': 2772,
#  'canned chicken broth': 1199,
#  'greens': 2863,
#  'duck': 2185,
#  'chinese rice wine': 1482,
#  'yu choy': 6169,
#  'sake': 4871,
#  'rice wine': 4753,
#  'firmly packed brown sugar': 2372,
#  'black sesame seeds': 866,
#  'firmly packed light brown sugar': 2373,
#  'rice stick noodles': 4748,
#  'fresh coriander': 2473,
#  'seedless cucumber': 4980,
#  'roasted peanuts': 4782,
#  'beets': 801,
#  'catfish fillets': 1269,
#  'seasoned rice wine vinegar': 4974,
#  'hot chili sauce': 3069,
#  'five-spice powder': 2386,
#  'teriyaki sauce': 5593,
#  'prawns': 4463,
#  'cornflour': 1810,
#  'black mustard seeds': 857,
#  'dark molasses': 1998,
#  'mixed spice': 3826,
#  'green cardamom': 2830,
#  'croissants': 1897,
#  'caster': 1265,
#  'ham hock': 2965,
#  'saffron threads': 4866,
#  'sea scallops': 4964,
#  'italian salad dressing': 3146,
#  'coconut oil': 1671,
#  'chile de arbol': 1418,
#  'dried shrimp': 2156,
#  'steel-cut oats': 5365,
#  'cashew nuts': 1258,
#  'peas': 4176,
#  'vanilla beans': 5810,
#  'pineapple': 4274,
#  'frozen pastry puff sheets': 2587,
#  'steamed rice': 5361,
#  'anchovy paste': 517,
#  'cornish hens': 1813,
#  'naan': 3890,
#  'tzatziki': 5756,
#  'vanilla wafer crumbs': 5829,
#  'cornichons': 1811,
#  'loin pork chops': 3494,
#  'cooking sherry': 1775,
#  'pork back ribs': 4375,
#  'bbq sauce': 728,
#  'sherry wine': 5042,
#  'boneless chicken breast': 935,
#  'black': 834,
#  'sugar cubes': 5426,
#  'coffee liqueur': 1688,
#  'dried fruit': 2117,
#  'fresh ginger root': 2482,
#  'turkey': 5726,
#  'vermicelli noodles': 5891,
#  'salad': 4873,
#  'pickled carrots': 4238,
#  'white radish': 5998,
#  'leaves': 3375,
#  'mint leaves': 3804,
#  'sweet soy sauce': 5496,
#  'creamy peanut butter': 1874,
#  'chillies': 1451,
#  'dried black beans': 2094,
#  'bacon slices': 659,
#  'pork shoulder boston butt': 4410,
#  'lower sodium chicken broth': 3613,
#  'orange slices': 4032,
#  'smoked ham hocks': 5193,
#  'ground white pepper': 2929,
#  'mushroom caps': 3875,
#  'spaghetti': 5294,
#  'smoked sausage': 5202,
#  'red bliss potato': 4613,
#  'artichokes': 582,
#  ...}

# %%
# get inverse document frequency
idf = vec.idf_

# %%
# make dictionary with features and respective idfs
d = dict(zip(vec.get_feature_names(), idf))

# %%
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
sorted_d[:10]
# Out:
# [('salt', 1.7921919912759123),
#  ('onions', 2.6007931430556033),
#  ('olive oil', 2.623311318524266),
#  ('water', 2.673496064460222),
#  ('garlic', 2.6797701730580297),
#  ('sugar', 2.827140558387348),
#  ('garlic cloves', 2.858035948400945),
#  ('butter', 3.0964469718459435),
#  ('ground black pepper', 3.110456265652729),
#  ('all-purpose flour', 3.1467931741656274)]

# %% [markdown]
# #### try naive bayes classifier

# %% [markdown]
# #### test a range of alphas

# %%
alphas = np.arange(0, 1, 0.1)

# %%
def get_nb_train_and_predictions(alpha):
    clf = MultinomialNB(alpha=alpha)
    clf.fit(train_data, y_train)
    pred = clf.predict(test_data)
    score = accuracy_score(y_test, pred)
    return score

# %%
for alpha in alphas:
    score = get_nb_train_and_predictions(alpha)
    print('Alpha:', alpha)
    print('Accuracy score:', score, '\n')
# Out:
# /home/nicole/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# Alpha: 0.0
# Accuracy score: 0.707864038616251
#
# Alpha: 0.1
# Accuracy score: 0.7470836685438456
#
# Alpha: 0.2
# Accuracy score: 0.7360217216411906
#
# Alpha: 0.30000000000000004
# Accuracy score: 0.7200321802091714
#
# Alpha: 0.4
# Accuracy score: 0.7085679806918745
#
# Alpha: 0.5
# Accuracy score: 0.6992156074014481
#
# Alpha: 0.6000000000000001
# Accuracy score: 0.6899637972646823
#
# Alpha: 0.7000000000000001
# Accuracy score: 0.6827232502011263
#
# Alpha: 0.8
# Accuracy score: 0.6740748189863234
#
# Alpha: 0.9
# Accuracy score: 0.6682421560740145

# %%
# use alpha = 0.1
nb_classifier = MultinomialNB(alpha=0.1)

# %%
nb_classifier.fit(train_data, y_train)
# Out:
# MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True)

# %%
pred = nb_classifier.predict(test_data)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.7470836685438456

# %%
# confusion_matrix(y_test, pred, labels=labels)

# %%
class_labels = nb_classifier.classes_

# %%
# extract feature
features = vec.get_feature_names()

# %%
# zip features and weights together for first class
feat_w_weights = sorted(zip(nb_classifier.coef_[0], features))

# %%
# top 10 features for first class
class_labels[0], feat_w_weights[:10]
# Out:
# ('brazilian',
#  [(-9.677381891052145, '(    oz.) tomato sauce'),
#   (-9.677381891052145, '(   oz.) tomato paste'),
#   (-9.677381891052145, '(10 oz.) frozen chopped spinach'),
#   (-9.677381891052145,
#    '(10 oz.) frozen chopped spinach, thawed and squeezed dry'),
#   (-9.677381891052145, '(14 oz.) sweetened condensed milk'),
#   (-9.677381891052145, '(14.5 oz.) diced tomatoes'),
#   (-9.677381891052145, '(15 oz.) refried beans'),
#   (-9.677381891052145, '1% low-fat buttermilk'),
#   (-9.677381891052145, '1% low-fat chocolate milk'),
#   (-9.677381891052145, '1% low-fat cottage cheese')])

# %%
# bottom 10 features for second class
class_labels[1], feat_w_weights[-10:]
# Out:
# ('british',
#  [(-5.030267324099119, 'garlic cloves'),
#   (-4.914952103984577, 'water'),
#   (-4.863621416835011, 'sugar'),
#   (-4.8311057823858095, 'coconut milk'),
#   (-4.723446697678546, 'olive oil'),
#   (-4.61841226879129, 'onions'),
#   (-4.569570693306051, 'salt'),
#   (-4.4419091232820005, 'lime'),
#   (-4.302054633712999, 'sweetened condensed milk'),
#   (-4.197400945851531, 'cachaca')])

# %% [raw]
# http://scikit-learn.org/stable/modules/multiclass.html

# %% [markdown]
# #### use pipeline with TFIDF and Logistic Regression classifier

# %%
logreg = OneVsRestClassifier(LogisticRegression(random_state=42))

# %%
logreg.fit(train_data, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1)

# %%
# get accurracy 
logreg.score(test_data, y_test)
# Out:
# 0.7676991150442478

# %%
y_prob = logreg.predict_proba(test_data)

# %%
labels = logreg.classes_

# %%
features = vec.get_feature_names()

# %%
# zip features and weights together for first class
feat_w_weights2 = sorted(zip(logreg.coef_[0], features))

# %% [markdown]
# #### try support vector classifier

# %%
svc = OneVsRestClassifier(LinearSVC(random_state=42))

# %%
svc.fit(train_data, y_train)
# Out:
# OneVsRestClassifier(estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=42, tol=0.0001,
#      verbose=0),
#           n_jobs=1)

# %%
svc.score(test_data, y_test)
# Out:
# 0.7844931617055511

# %% [markdown]
# #### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=42)

# %%
rf.fit(train_data, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
rf.score(test_data, y_test)
# Out:
# 0.6601971037811746

# %% [markdown]
# #### using multioutput classifier

# %%
from sklearn.multioutput import MultiOutputClassifier

# %%
moc_rf = MultiOutputClassifier(rf)

# %%
y_train.shape
# Out:
# (29830,)

# %%
# reshape target to be 2D
y_train = y_train.reshape(-1, 1)
# Out:
# /home/nicole/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
moc_rf.fit(train_data, y_train)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#            n_jobs=1)

# %%
y_test = y_test.reshape(-1, 1)
# Out:
# /home/nicole/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
moc_rf.score(test_data, y_test)
# Out:
# 0.6601971037811746

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(train_data, y_train)
# Out:
# /home/nicole/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knn.score(test_data, y_test)
# Out:
# 0.7120876910699919

# %% [markdown]
# #### initial model using Logistic Regression and Tfidf vectorizer

# %%
corpus
# Out:
# ['romaine lettuce',
#  'black olives',
#  'grape tomatoes',
#  'garlic',
#  'pepper',
#  'purple onion',
#  'seasoning',
#  'garbanzo beans',
#  'feta cheese crumbles',
#  'plain flour',
#  'ground pepper',
#  'salt',
#  'tomatoes',
#  'ground black pepper',
#  'thyme',
#  'eggs',
#  'green tomatoes',
#  'yellow corn meal',
#  'milk',
#  'vegetable oil',
#  'eggs',
#  'pepper',
#  'salt',
#  'mayonaise',
#  'cooking oil',
#  'green chilies',
#  'grilled chicken breasts',
#  'garlic powder',
#  'yellow onion',
#  'soy sauce',
#  'butter',
#  'chicken livers',
#  'water',
#  'vegetable oil',
#  'wheat',
#  'salt',
#  'black pepper',
#  'shallots',
#  'cornflour',
#  'cayenne pepper',
#  'onions',
#  'garlic paste',
#  'milk',
#  'butter',
#  'salt',
#  'lemon juice',
#  'water',
#  'chili powder',
#  'passata',
#  'oil',
#  'ground cumin',
#  'boneless chicken skinless thigh',
#  'garam masala',
#  'double cream',
#  'natural yogurt',
#  'bay leaf',
#  'plain flour',
#  'sugar',
#  'butter',
#  'eggs',
#  'fresh ginger root',
#  'salt',
#  'ground cinnamon',
#  'milk',
#  'vanilla extract',
#  'ground ginger',
#  'powdered sugar',
#  'baking powder',
#  'olive oil',
#  'salt',
#  'medium shrimp',
#  'pepper',
#  'garlic',
#  'chopped cilantro',
#  'jalapeno chilies',
#  'flat leaf parsley',
#  'skirt steak',
#  'white vinegar',
#  'sea salt',
#  'bay leaf',
#  'chorizo sausage',
#  'sugar',
#  'pistachio nuts',
#  'white almond bark',
#  'flour',
#  'vanilla extract',
#  'olive oil',
#  'almond extract',
#  'eggs',
#  'baking powder',
#  'dried cranberries',
#  'olive oil',
#  'purple onion',
#  'fresh pineapple',
#  'pork',
#  'poblano peppers',
#  'corn tortillas',
#  'cheddar cheese',
#  'ground black pepper',
#  'salt',
#  'iceberg lettuce',
#  'lime',
#  'jalapeno chilies',
#  'chopped cilantro fresh',
#  'chopped tomatoes',
#  'fresh basil',
#  'garlic',
#  'extra-virgin olive oil',
#  'kosher salt',
#  'flat leaf parsley',
#  'pimentos',
#  'sweet pepper',
#  'dried oregano',
#  'olive oil',
#  'garlic',
#  'sharp cheddar cheese',
#  'pepper',
#  'swiss cheese',
#  'provolone cheese',
#  'canola oil',
#  'mushrooms',
#  'black olives',
#  'sausages',
#  'low sodium soy sauce',
#  'fresh ginger',
#  'dry mustard',
#  'green beans',
#  'white pepper',
#  'sesame oil',
#  'scallions',
#  'canola oil',
#  'sugar',
#  'Shaoxing wine',
#  'garlic',
#  'ground turkey',
#  'water',
#  'crushed red pepper flakes',
#  'corn starch',
#  'Italian parsley leaves',
#  'walnuts',
#  'hot red pepper flakes',
#  'extra-virgin olive oil',
#  'fresh lemon juice',
#  'trout fillet',
#  'garlic cloves',
#  'chipotle chile',
#  'fine sea salt',
#  'flat leaf parsley',
#  'ground cinnamon',
#  'fresh cilantro',
#  'chili powder',
#  'ground coriander',
#  'kosher salt',
#  'ground black pepper',
#  'garlic',
#  'plum tomatoes',
#  'avocado',
#  'lime juice',
#  'flank steak',
#  'salt',
#  'ground cumin',
#  'black pepper',
#  'olive oil',
#  'crushed red pepper flakes',
#  'onions',
#  'fresh parmesan cheese',
#  'butter',
#  'all-purpose flour',
#  'fat free less sodium chicken broth',
#  'chopped fresh chives',
#  'gruyere cheese',
#  'ground black pepper',
#  'bacon slices',
#  'gnocchi',
#  'fat free milk',
#  'cooking spray',
#  'salt',
#  'tumeric',
#  'vegetable stock',
#  'tomatoes',
#  'garam masala',
#  'naan',
#  'red lentils',
#  'red chili peppers',
#  'onions',
#  'spinach',
#  'sweet potatoes',
#  'greek yogurt',
#  'lemon curd',
#  'confectioners sugar',
#  'raspberries',
#  'italian seasoning',
#  'broiler-fryer chicken',
#  'mayonaise',
#  'zesty italian dressing',
#  'sugar',
#  'hot chili',
#  'asian fish sauce',
#  'lime juice',
#  'soy sauce',
#  'vegetable oil',
#  'red bell pepper',
#  'chicken broth',
#  'yellow squash',
#  'garlic chili sauce',
#  'sliced green onions',
#  'broccolini',
#  'salt',
#  'fresh lime juice',
#  'cooked rice',
#  'chicken breasts',
#  'corn starch',
#  'pork loin',
#  'roasted peanuts',
#  'chopped cilantro fresh',
#  'hoisin sauce',
#  'creamy peanut butter',
#  'chopped fresh mint',
#  'thai basil',
#  'rice',
#  'medium shrimp',
#  'water',
#  'rice noodles',
#  'beansprouts',
#  'roma tomatoes',
#  'kosher salt',
#  'purple onion',
#  'jalapeno chilies',
#  'lime',
#  'chopped cilantro',
#  'low-fat mayonnaise',
#  'pepper',
#  'salt',
#  'baking potatoes',
#  'eggs',
#  'spicy brown mustard',
#  'sesame seeds',
#  'red pepper',
#  'yellow peppers',
#  'water',
#  'extra firm tofu',
#  'broccoli',
#  'soy sauce',
#  'orange bell pepper',
#  'arrowroot powder',
#  'fresh ginger',
#  'sesame oil',
#  'red curry paste',
#  'marinara sauce',
#  'flat leaf parsley',
#  'olive oil',
#  'linguine',
#  'capers',
#  'crushed red pepper flakes',
#  'olives',
#  'lemon zest',
#  'garlic',
#  'sugar',
#  'lo mein noodles',
#  'salt',
#  'chicken broth',
#  'light soy sauce',
#  'flank steak',
#  'beansprouts',
#  'dried black mushrooms',
#  'pepper',
#  'chives',
#  'oyster sauce',
#  'dark soy sauce',
#  'peanuts',
#  'sesame oil',
#  'cabbage',
#  'herbs',
#  'lemon juice',
#  'fresh tomatoes',
#  'paprika',
#  'mango',
#  'stock',
#  'chile pepper',
#  'onions',
#  'red chili peppers',
#  'oil',
#  'ground black pepper',
#  'butter',
#  'sliced mushrooms',
#  'sherry',
#  'salt',
#  'grated parmesan cheese',
#  'heavy cream',
#  'spaghetti',
#  'chicken broth',
#  'cooked chicken',
#  'all-purpose flour',
#  'green bell pepper',
#  'egg roll wrappers',
#  'sweet and sour sauce',
#  'corn starch',
#  'molasses',
#  'vegetable oil',
#  'oil',
#  'soy sauce',
#  'shredded cabbage',
#  'garlic',
#  'onions',
#  'fresh ginger root',
#  'ground pork',
#  'carrots',
#  'flour tortillas',
#  'cheese',
#  'breakfast sausages',
#  'large eggs',
#  'yellow corn meal',
#  'boiling water',
#  'butter',
#  'fresh parmesan cheese',
#  'sea salt',
#  'chicken broth',
#  'chicken breasts',
#  'hot sauce',
#  'red bell pepper',
#  'potatoes',
#  'bacon',
#  'garlic cloves',
#  'fresh parsley',
#  'andouille sausage',
#  'cajun seasoning',
#  'peanut oil',
#  'celery',
#  'ground red pepper',
#  'all-purpose flour',
#  'shrimp',
#  'onions',
#  'chili powder',
#  'crushed red pepper flakes',
#  'garlic powder',
#  'sea salt',
#  'ground cumin',
#  'onion powder',
#  'dried oregano',
#  'ground black pepper',
#  'paprika',
#  'eggs',
#  'shallots',
#  'firm tofu',
#  'beansprouts',
#  'turnips',
#  'palm sugar',
#  'vegetable oil',
#  'garlic cloves',
#  'sliced chicken',
#  'fish sauce',
#  'lime wedges',
#  'roasted peanuts',
#  'green papaya',
#  'chile powder',
#  'ground black pepper',
#  'tamarind paste',
#  'chinese chives',
#  'olive oil',
#  'onions',
#  'crushed garlic',
#  'dried oregano',
#  'green onions',
#  'white sugar',
#  'dried basil',
#  'diced tomatoes',
#  'olive oil',
#  'diced tomatoes',
#  'Johnsonville Andouille Dinner Sausage',
#  'parsley',
#  'shrimp',
#  'jambalaya rice mix',
#  'worcestershire sauce',
#  'hot pepper sauce',
#  'creole seasoning',
#  'olive oil',
#  'bread slices',
#  'great northern beans',
#  'garlic cloves',
#  'pepper',
#  'shrimp',
#  'sage leaves',
#  'salt',
#  'chicken broth',
#  'cooking oil',
#  'chinese five-spice powder',
#  'ground black pepper',
#  'salt',
#  'sugar',
#  'crushed garlic',
#  'chicken thighs',
#  'soy sauce',
#  'star anise',
#  'green onions',
#  'cream cheese',
#  'shredded cheddar cheese',
#  'cayenne pepper',
#  'chili powder',
#  'garlic cloves',
#  'black-eyed peas',
#  'tortilla chips',
#  'collard greens',
#  'extra-virgin olive oil',
#  'ham hock',
#  'chicken stock',
#  'apple cider',
#  'freshly ground pepper',
#  'chile powder',
#  'bay leaves',
#  'salt',
#  'rib',
#  'light brown sugar',
#  'large garlic cloves',
#  'cayenne pepper',
#  'onions',
#  'Oscar Mayer Deli Fresh Smoked Ham',
#  'hoagie rolls',
#  'salami',
#  'giardiniera',
#  'mozzarella cheese',
#  'pepperoni',
#  'butter',
#  'italian seasoning',
#  'ice cubes',
#  'club soda',
#  'white rum',
#  'lime',
#  'turbinado',
#  'cooked chicken',
#  'enchilada sauce',
#  'sliced green onions',
#  'picante sauce',
#  'green pepper',
#  'corn tortillas',
#  'canned black beans',
#  'shredded lettuce',
#  'sour cream',
#  'shredded cheddar cheese',
#  'garlic cloves',
#  'canola oil',
#  'salmon fillets',
#  'shallots',
#  'cumin seed',
#  'fresh cilantro',
#  'salt',
#  'curry powder',
#  'vegetable oil',
#  'serrano chile',
#  'fresh ginger',
#  'sauce',
#  'tomatoes',
#  'chicken breast halves',
#  'chopped cilantro fresh',
#  'white vinegar',
#  'jalapeno chilies',
#  'salt',
#  'black pepper',
#  'vegetable oil',
#  'avocado',
#  'lettuce leaves',
#  'chopped onion',
#  'eggs',
#  'mandarin oranges',
#  'water',
#  'orange liqueur',
#  'yellow cake mix',
#  'frosting',
#  'vegetable oil',
#  'white sugar',
#  'sugar',
#  'salt',
#  'fennel bulb',
#  'water',
#  'lemon olive oil',
#  'grapefruit juice',
#  'sugar',
#  'all-purpose flour',
#  'vegetable oil',
#  'white cornmeal',
#  'baking powder',
#  'onions',
#  'bacon drippings',
#  'buttermilk',
#  'butter',
#  'crab boil',
#  'garlic',
#  'old bay seasoning',
#  'cream cheese',
#  'crawfish',
#  'salt',
#  'mayonaise',
#  'white sugar',
#  'ground black pepper',
#  'salt',
#  'white vinegar',
#  'lemon juice',
#  'sirloin',
#  'mirin',
#  'yellow onion',
#  'low sodium soy sauce',
#  'water',
#  'corn oil',
#  'sugar',
#  'green onions',
#  'glass noodles',
#  'sake',
#  'shiitake',
#  'napa cabbage',
#  'large eggs',
#  'whipping cream',
#  'chicken broth',
#  'ground red pepper',
#  'extra sharp cheddar cheese',
#  'quickcooking grits',
#  'hot sauce',
#  'ground black pepper',
#  'worcestershire sauce',
#  'monterey jack',
#  'fresh basil',
#  'bay leaves',
#  'crushed red pepper',
#  'mussels',
#  'olive oil',
#  'basil',
#  'garlic cloves',
#  'black pepper',
#  'dry white wine',
#  'salt',
#  'tomatoes',
#  'finely chopped onion',
#  'linguine',
#  'flat leaf parsley',
#  'sugar',
#  'large eggs',
#  'all-purpose flour',
#  'baking soda',
#  'buttermilk',
#  'honey',
#  'corn oil',
#  'yellow corn meal',
#  'unsalted butter',
#  'salt',
#  'lemon',
#  'pesto',
#  'salmon fillets',
#  'white wine',
#  'bread crumbs',
#  'unsalted butter',
#  'onion powder',
#  'curry',
#  'low sodium beef broth',
#  'pickapeppa sauce',
#  'curry powder',
#  'bay leaves',
#  'garlic',
#  'cayenne pepper',
#  'cold water',
#  'pepper',
#  'large eggs',
#  'extra-virgin olive oil',
#  'yellow onion',
#  'allspice',
#  'white vinegar',
#  'kosher salt',
#  'fresh thyme',
#  'worcestershire sauce',
#  'all-purpose flour',
#  'ground beef',
#  'melted butter',
#  'matcha green tea powder',
#  'white sugar',
#  'milk',
#  'all-purpose flour',
#  'eggs',
#  'salt',
#  'baking powder',
#  'chopped walnuts',
#  'coarse salt',
#  'fenugreek',
#  'urad dal',
#  'potatoes',
#  'white rice',
#  'vegetable oil',
#  'pizza crust',
#  'plum tomatoes',
#  'pesto',
#  'part-skim mozzarella cheese',
#  'cooking spray',
#  'salt',
#  'black pepper',
#  'yukon gold potatoes',
#  'low-fat sour cream',
#  'leeks',
#  'olive oil',
#  '1% low-fat milk',
#  'sugar',
#  'chicken thighs',
#  'cooking oil',
#  'fish sauce',
#  'garlic',
#  'black pepper',
#  'lemongrass',
#  'large garlic cloves',
#  'rice',
#  'unsweetened coconut milk',
#  'fresh ginger',
#  'peanut sauce',
#  'spareribs',
#  'sesame oil',
#  'tamari soy sauce',
#  'golden brown sugar',
#  'dry sherry',
#  'boiling water',
#  'chicken legs',
#  'chile pepper',
#  'ghee',
#  'tomato paste',
#  'fresh ginger root',
#  'garlic',
#  'chopped cilantro fresh',
#  'water',
#  'vegetable oil',
#  'onions',
#  'tomatoes',
#  'garam masala',
#  'cumin seed',
#  'ground turmeric',
#  'stock',
#  'curry powder',
#  'cracked black pepper',
#  'minced beef',
#  'onions',
#  'plain flour',
#  'bread crumbs',
#  'butter',
#  'garlic',
#  'celery',
#  'cold water',
#  'tumeric',
#  'dried thyme',
#  'ginger',
#  'oil',
#  'tomatoes',
#  'water',
#  'paprika',
#  'salt',
#  'chillies',
#  'crushed tomatoes',
#  'garlic',
#  'fresh rosemary',
#  'ground black pepper',
#  'onions',
#  'olive oil',
#  'boneless pork loin',
#  'kosher salt',
#  'pappardelle',
#  'extra firm tofu',
#  'coconut milk',
#  'fresh basil',
#  'red curry paste',
#  'eggplant',
#  'red bell pepper',
#  'vegetable oil',
#  'onions',
#  'jasmine rice',
#  'garlic',
#  'scallions',
#  'sugar',
#  'shiitake',
#  'Gochujang base',
#  'beansprouts',
#  'top round steak',
#  'sesame seeds',
#  'rice vinegar',
#  'carrots',
#  'soy sauce',
#  'sesame oil',
#  'Taiwanese bok choy',
#  'vanilla',
#  'milk',
#  'large egg yolks',
#  'sugar',
#  'corn starch',
#  'orange juice concentrate',
#  'pumpkin purée',
#  'marshmallow creme',
#  'toasted pecans',
#  'maple syrup',
#  'ground cinnamon',
#  'gingersnap',
#  'ground nutmeg',
#  'cream cheese',
#  'black pepper',
#  'white sugar',
#  'white vinegar',
#  'salt',
#  'bacon',
#  'brown sugar',
#  'green beans',
#  'large eggs',
#  'serrano ham',
#  'manchego cheese',
#  'butter',
#  'dijon mustard',
#  'sourdough',
#  'membrillo',
#  'burger buns',
#  'fresh cilantro',
#  'chili powder',
#  'garlic cloves',
#  'panko breadcrumbs',
#  'chickpea flour',
#  'pepper',
#  'Sriracha',
#  'chickpeas',
#  'carrots',
#  'ground flaxseed',
#  'soy sauce',
#  'olive oil',
#  'salt',
#  'lemon juice',
#  'greens',
#  'spinach',
#  'curry powder',
#  'tahini',
#  'scallions',
#  'onions',
#  'ground cumin',
#  'ground cloves',
#  'whole nutmegs',
#  'ground ginger',
#  'ground coriander',
#  'ground cinnamon',
#  'ground cardamom',
#  'ground black pepper',
#  'ground cumin',
#  'tomatoes',
#  'red pepper',
#  'olive oil',
#  'Italian bread',
#  'balsamic vinegar',
#  'onions',
#  'fresh basil',
#  'garlic',
#  'sausage casings',
#  'ground black pepper',
#  'garlic',
#  'honey',
#  'grated parmesan cheese',
#  'shredded mozzarella cheese',
#  'kosher salt',
#  'roasted red peppers',
#  'penne pasta',
#  'olive oil',
#  'crushed red pepper flakes',
#  'tumeric',
#  'olive oil',
#  'lemon',
#  'saffron',
#  'tomato paste',
#  'pepper',
#  'flour',
#  'chickpeas',
#  'chicken stock',
#  'warm water',
#  'fresh ginger',
#  'salt',
#  'tomatoes',
#  'fresh cilantro',
#  'shallots',
#  'fresh parsley',
#  'ground pepper',
#  'paprika',
#  'ground cardamom',
#  'chopped cilantro fresh',
#  'preserved lemon',
#  'harissa',
#  'salt',
#  'couscous',
#  'tomato paste',
#  'cayenne',
#  'garlic',
#  'fat skimmed chicken broth',
#  'ground turmeric',
#  'pitted kalamata olives',
#  'diced tomatoes',
#  'fat',
#  'onions',
#  'sweetened condensed milk',
#  'ice',
#  'espresso',
#  'top round steak',
#  'vegetable oil',
#  'shiitake',
#  'soy sauce',
#  'fresh asparagus',
#  'green onions',
#  'avocado',
#  'chopped cilantro fresh',
#  'jalapeno chilies',
#  'finely chopped onion',
#  'plum tomatoes',
#  'green chilies',
#  'pecans',
#  'golden brown sugar',
#  'crumbled blue cheese',
#  'garlic cloves',
#  'chuck',
#  'hamburger buns',
#  'hot pepper sauce',
#  'creole seasoning',
#  'onions',
#  'mayonaise',
#  'ground black pepper',
#  'salt',
#  'okra pods',
#  'andouille sausage',
#  'olive oil',
#  'watercress',
#  'fresh lemon juice',
#  'sugar',
#  'vanilla',
#  'eggs',
#  'self rising flour',
#  'confectioners sugar',
#  'milk',
#  'softened butter',
#  'food colouring',
#  'butter',
#  'Madeira',
#  'foie gras',
#  'demi-glace',
#  'sherry vinegar',
#  'whipping cream',
#  'white bread',
#  'Fuyu persimmons',
#  'salt',
#  'egg bread',
#  'watercress',
#  'fenugreek leaves',
#  'olive oil',
#  'garlic',
#  'black mustard seeds',
#  'ground cumin',
#  'amchur',
#  'lime wedges',
#  'scallions',
#  'coriander',
#  'sugar',
#  'fingerling potatoes',
#  'green chilies',
#  'chopped cilantro',
#  'tumeric',
#  'fresh ginger root',
#  'salt',
#  'ramps',
#  'black peppercorns',
#  'cinnamon sticks',
#  'cardamom pods',
#  'cumin seed',
#  'coriander seeds',
#  'spinach',
#  'asiago',
#  'whole wheat pasta',
#  'olive oil',
#  'sweet onion',
#  'garlic',
#  'grape tomatoes',
#  'mushrooms',
#  'chestnuts',
#  'granulated sugar',
#  'whole milk ricotta cheese',
#  'coffee ice cream',
#  'large eggs',
#  'mascarpone',
#  'rum',
#  'powdered sugar',
#  'semisweet chocolate',
#  'chestnut flour',
#  'baby spinach leaves',
#  'naan',
#  'unsalted butter',
#  'chopped garlic',
#  'water',
#  'large shrimp',
#  'tomatoes',
#  'salt',
#  'water',
#  'barley',
#  'cooked ham',
#  'red bell pepper',
#  'seasoning',
#  'potatoes',
#  'olive oil',
#  'onions',
#  'eggs',
#  'bacon',
#  'salt',
#  'starchy potatoes',
#  'grated nutmeg',
#  'flour',
#  'ground black pepper',
#  'all-purpose flour',
#  'milk',
#  'buttermilk',
#  'sirloin tip roast',
#  'coarse salt',
#  'steak',
#  'vegetable oil',
#  'cayenne pepper',
#  'granulated sugar',
#  'all-purpose flour',
#  'vegetable shortening',
#  'baking powder',
#  'milk',
#  'salt',
#  'ground pork',
#  'finely chopped fresh parsley',
#  'onions',
#  'salt',
#  'vinegar',
#  'caul fat',
#  'ground cinnamon',
#  'whole milk',
#  'golden brown sugar',
#  'heavy whipping cream',
#  'kahlúa',
#  'corn starch',
#  'instant espresso powder',
#  'boneless chicken skinless thigh',
#  'lime',
#  'epazote',
#  'bay leaf',
#  'lime juice',
#  'radishes',
#  'salt',
#  'oregano',
#  'white onion',
#  'hominy',
#  'garlic',
#  'chopped cilantro',
#  'avocado',
#  'fresh cilantro',
#  'tomatillos',
#  'pepitas',
#  'canola oil',
#  'catfish fillets',
#  'ground black pepper',
#  'salt',
#  'dried thyme',
#  'ground red pepper',
#  'peanut oil',
#  'yellow corn meal',
#  'large eggs',
#  'all-purpose flour',
#  'garlic powder',
#  'buttermilk',
#  'olive oil',
#  'sea salt',
#  'coconut milk',
#  'water',
#  'garam masala',
#  'ground coriander',
#  'basmati rice',
#  'cauliflower',
#  'fresh ginger',
#  'green chilies',
#  'onions',
#  'fresh cilantro',
#  'potatoes',
#  'scallions',
#  'cumin',
#  'olive oil',
#  'olives',
#  'salt',
#  'blood orange',
#  'freshly ground pepper',
#  'fennel bulb',
#  'balsamic vinegar',
#  'low salt chicken broth',
#  'dijon mustard',
#  'corn starch',
#  'dried basil',
#  'garlic cloves',
#  'white wine vinegar',
#  'tomato sauce',
#  'shredded carrots',
#  'spinach',
#  'part-skim mozzarella cheese',
#  'italian seasoning',
#  'english muffins, split and toasted',
#  'chopped onion',
#  'vegetable oil cooking spray',
#  'chopped green bell pepper',
#  'prawns',
#  'rice flour',
#  'seasoning salt',
#  'salt',
#  'vegetable oil',
#  'club soda',
#  ...]

# %% [raw]
# https://buhrmann.github.io/tfidf-analysis.html

# %%
vectorizer = TfidfVectorizer(min_df=1, stop_words='english')
X = vectorizer.fit_transform(corpus)
idf = vectorizer.idf_
d = dict(zip(vectorizer.get_feature_names(), idf))
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
sorted_d[:50]

# %%
def plot_tfidf_classfeats_h(dfs):
    ''' Plot the data frames returned by the function plot_tfidf_classfeats(). '''
    fig = plt.figure(figsize=(12, 9), facecolor="w")
    x = np.arange(len(dfs[0]))
    for i, df in enumerate(dfs):
        ax = fig.add_subplot(1, len(dfs), i+1)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.set_frame_on(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_xlabel("Mean Tf-Idf Score", labelpad=16, fontsize=14)
        ax.set_title("label = " + str(df.label), fontsize=16)
        ax.ticklabel_format(axis='x', style='sci', scilimits=(-2,2))
        ax.barh(x, df.tfidf, align='center', color='#3F5D7D')
        ax.set_yticks(x)
        ax.set_ylim([-1, x[-1]+1])
        yticks = ax.set_yticklabels(df.feature)
        plt.subplots_adjust(bottom=0.09, right=0.97, left=0.15, top=0.95, wspace=0.52)
    plt.show()

# %%
# to get top features
def top_tfidf_feats(row, features, top_n=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df

# %%
cuisine_ingredients = cuisine_train.groupby('cuisine')['ingredients'].apply(list)

# %%
cuisine_ingredients[0]
